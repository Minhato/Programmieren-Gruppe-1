# %%
from datetime import *

print(datetime.strftime(datetime.now(), "%Y")) #jahr
print(datetime.strftime(datetime.now(), "%m")) #monat
print(datetime.strftime(datetime.now(), "%d")) # tag
print(datetime.strftime(datetime.now(), "%H")) #stunde
print(datetime.strftime(datetime.now(), "%M")) #Minute
# Out:
# 2021
# 06
# 10
# 01
# 44

# %%
y = datetime(2021,6,10)
print(datetime.strftime(y, "%Y")) #jahr
# Out:
# 2021

# %%
print(datetime.strftime("2021-06-10", "%Y")) #jahr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-68c88331695b> in <module>
# ----> 1 print(datetime.strftime("2021-06-10", "%Y")) #jahr
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'str' object

# %%
y = datetime.strptime("2021.06.10","%Y" "." "%m" "." "%d")
date.strftime(y, "%Y")
# Out:
# '2021'

# %%
y = datetime.strptime("2021-6-10","%Y" "-" "%m" "-" "%d")
datetime.strftime(y, "%Y")
# Out:
# '2021'

# %%
y = datetime.strptime("15:30:00", "%H" ":" "%M")
y = datetime.time(y).strftime("%H")
print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0dc7cf63d365> in <module>
# ----> 1 y = datetime.strptime("15:30:00", "%H" ":" "%M")
#       2 y = datetime.time(y).strftime("%H")
#       3 print(y)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.1520.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.1520.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains: :00

# %%
y = "2021-06-15T03:00:00+02:00"
x = datetime.strptime(y, "%Y-%m-%d" "T" "%H:%M:%S" "%z")
print(x)
print(type(x))
# Out:
# 2021-06-15 03:00:00+02:00
# <class 'datetime.datetime'>

# %%
liste = [1,5 , 23 , 423 , 543]
einString = ""

for werte in liste:
    einString += str(werte) + "\n"
print(einString)
# Out:
# 1/n5/n23/n423/n543/n

# %%
pp = Logik()

pp.intend = "erstellen"

if pp.intend != "erstellen":
    print("kein Intent")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44d9ddb8834e> in <module>
# ----> 1 pp.intend = "erstellen"
#       2
#       3 if pp.intend != "erstellen":
#       4     print("kein Intent")
#
# NameError: name 'pp' is not defined
